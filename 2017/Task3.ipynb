# %%
import numpy as np
import pandas as pd
import re
import pymorphy2
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
from sklearn.feature_extraction.text import TfidfVectorizer
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA, LatentDirichletAllocation
from sklearn.manifold import TSNE
from collections import Counter
from sklearn.ensemble import RandomForestClassifier
import editdistance

# %%
with open("/Users/alexajax/Downloads/dataset_40412_2.txt", encoding='utf-8') as f:
    data = f.read().splitlines()

# %%
import wikipedia
wikipedia.set_lang("ru")

# %%
categories = ['Персоналии по алфавиту',
'Населённые пункты по алфавиту',
'Спортсмены по алфавиту', 
'Водные объекты по алфавиту',
'Учёные по алфавиту',
'Реки по алфавиту',
'Животные по алфавиту',
'Футболисты по алфавиту',
'Кавалеры ордена Ленина',
'Фильмы по алфавиту',
'Музыканты по алфавиту',
'Писатели по алфавиту',
'Умершие в Москве',
'Альбомы по алфавиту',
'Статьи проекта Биология',
'Герои Советского Союза',
'Родившиеся в Москве',
'Актёры по алфавиту',
'Растения по алфавиту',
'Компании по алфавиту',
'Члены КПСС',
'Актрисы по алфавиту',
'Улицы по алфавиту',
'Музыкальные коллективы по алфавиту',
'Политики по алфавиту',
'Умершие в Санкт-Петербурге',
'Награждённые медалью «За победу над Германией в Великой Отечественной войне 1941—1945 гг.»',
'Родившиеся в Санкт-Петербурге',
'Галактики по алфавиту',
'Компьютерные игры по алфавиту',
'Синглы по алфавиту',
'Виды вне опасности',
'Участники Первой мировой войны',
'Футбольные клубы по алфавиту',
'Умершие в Париже',
'Офицеры СССР',
'Актёры XXI века']

# %%
categories = dict(enumerate(list(map(lambda x: 'Категория:' + x, categories)), 1))
categories = {v: k for k, v in categories.items()}

# %%
categories
# Out:
# {'Категория:Актрисы по алфавиту': 22,
#  'Категория:Актёры XXI века': 37,
#  'Категория:Актёры по алфавиту': 18,
#  'Категория:Альбомы по алфавиту': 14,
#  'Категория:Виды вне опасности': 32,
#  'Категория:Водные объекты по алфавиту': 4,
#  'Категория:Галактики по алфавиту': 29,
#  'Категория:Герои Советского Союза': 16,
#  'Категория:Животные по алфавиту': 7,
#  'Категория:Кавалеры ордена Ленина': 9,
#  'Категория:Компании по алфавиту': 20,
#  'Категория:Компьютерные игры по алфавиту': 30,
#  'Категория:Музыкальные коллективы по алфавиту': 24,
#  'Категория:Музыканты по алфавиту': 11,
#  'Категория:Награждённые медалью «За победу над Германией в Великой Отечественной войне 1941—1945 гг.»': 27,
#  'Категория:Населённые пункты по алфавиту': 2,
#  'Категория:Офицеры СССР': 36,
#  'Категория:Персоналии по алфавиту': 1,
#  'Категория:Писатели по алфавиту': 12,
#  'Категория:Политики по алфавиту': 25,
#  'Категория:Растения по алфавиту': 19,
#  'Категория:Реки по алфавиту': 6,
#  'Категория:Родившиеся в Москве': 17,
#  'Категория:Родившиеся в Санкт-Петербурге': 28,
#  'Категория:Синглы по алфавиту': 31,
#  'Категория:Спортсмены по алфавиту': 3,
#  'Категория:Статьи проекта Биология': 15,
#  'Категория:Улицы по алфавиту': 23,
#  'Категория:Умершие в Москве': 13,
#  'Категория:Умершие в Париже': 35,
#  'Категория:Умершие в Санкт-Петербурге': 26,
#  'Категория:Участники Первой мировой войны': 33,
#  'Категория:Учёные по алфавиту': 5,
#  'Категория:Фильмы по алфавиту': 10,
#  'Категория:Футболисты по алфавиту': 8,
#  'Категория:Футбольные клубы по алфавиту': 34,
#  'Категория:Члены КПСС': 21}

# %%
import re

# %%
from tqdm import tqdm

# %%
def categorize(piece):
    page_categories = []
    
    search_param = piece.split('—')[0].rstrip(' ').replace('‘', "'")
    print(search_param)
    
    print()
    
#    res = (wikipedia.search(search_param)\
#           +wikipedia.search(strip_accents(search_param))\
#           +wikipedia.search(' '.join(search_param.split()[:2]))\
#           +wikipedia.search(search_param.split()[0]))[:5]

    res = (wikipedia.search(search_param) + wikipedia.search(strip_accents(search_param)))[:4]
    print(res)
    


    distances = []
    for p in res:
        try:
            distances.append(editdistance.eval(wikipedia.page(p).content[:len(piece)], piece))
        except:
            distances.append(float('inf'))
    page = wikipedia.page(res[np.argmin(np.array(distances))])
    
    
    for cat in sorted(page.categories):
        if not cat.startswith('Категория:Википедия:'):
            print(cat)
    print()
    
    for category in categories.keys():
        if category in page.categories:
            page_categories.append(categories[category])
            print(category)
    
    print(sorted(page_categories))
    print("", end='\n\n\n')
    return sorted(page_categories)

# %%
data_categories = []
for piece in tqdm(data):
    if piece.startswith("«Игра́й!» — первый альбом"):
        data_categories.append([14])
        continue
    data_categories.append(categorize(piece))
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# Нётома
#
# ['Нетома', 'Черча', 'Макаровка (приток Нетомы)', 'Шойкаполда']
#   3%|▎         | 1/30 [00:08<04:08,  8.56s/it]
# Категория:Водные объекты по алфавиту
# Категория:Карточка реки: Викиданные: используется свойство: код ГВР
# Категория:Карточка реки: заполнить: Расход воды
# Категория:Карточка реки: исправить: Устье
# Категория:Карточка реки: исправить: Устье/Бассейн
# Категория:Незавершённые статьи по географии Архангельской области
# Категория:Незавершённые статьи по географии Карелии
# Категория:ПРО:ВО:Крайняя правка: в прошлом году
# Категория:Притоки Водлы
# Категория:Реки Балтийского бассейнового округа
# Категория:Реки Плесецкого района
# Категория:Реки Пудожского района
# Категория:Реки до 500 км в длину
# Категория:Реки по алфавиту
#
# Категория:Реки по алфавиту
# Категория:Водные объекты по алфавиту
# [4, 6]
#
#
#
# Абда́лка или Абда́льская (укр. Абдалка, крымско-тат. Abdal, Абдал), ранее называлась Боурча[2][3]
#
# ['Абдалка']
#   7%|▋         | 2/30 [00:12<03:18,  7.07s/it]
# Категория:Бассейн Салгира
# Категория:Водные объекты по алфавиту
# Категория:Карточка реки: заполнить: Бассейн
# Категория:Карточка реки: заполнить: Координаты истока
# Категория:Карточка реки: заполнить: Национальное название
# Категория:Карточка реки: заполнить: Площадь бассейна
# Категория:Карточка реки: заполнить: Расход воды
# Категория:Незавершённые статьи по географии Крыма
# Категория:ПРО:ВО:Крайняя правка: в прошлом году
# Категория:Реки Крыма
# Категория:Реки до 10 км в длину
# Категория:Реки по алфавиту
#
# Категория:Реки по алфавиту
# Категория:Водные объекты по алфавиту
# [4, 6]
#
#
#
# Драгоча
#
# ['Драгоча', 'Тьмака', 'Тьма (река)', 'Рачайна']
#  10%|█         | 3/30 [00:20<03:22,  7.48s/it]
# Категория:Водные объекты по алфавиту
# Категория:Карточка реки: Викиданные: используется свойство: код ГВР
# Категория:Карточка реки: заполнить: Координаты истока
# Категория:Карточка реки: заполнить: Площадь бассейна
# Категория:Карточка реки: заполнить: Расход воды
# Категория:Незавершённые статьи по географии Тверской области
# Категория:ПРО:ВО:Крайняя правка: в прошлом году
# Категория:Притоки Волги
# Категория:Реки Верхневолжского бассейнового округа
# Категория:Реки Зубцовского района
# Категория:Реки до 50 км в длину
# Категория:Реки по алфавиту
#
# Категория:Реки по алфавиту
# Категория:Водные объекты по алфавиту
# [4, 6]
#
#
#
# «Челове́к дождя́» (англ. Rain Man)
#
# ['Человек дождя', 'Пурпурный дождь', 'Purple Rain', 'Rain (песня The Beatles)']
#  13%|█▎        | 4/30 [00:28<03:20,  7.71s/it]
# Категория:Аутизм в кино
# Категория:Бадди-муви
# Категория:Статьи со ссылками на Викицитатник
# Категория:Фильмы 1988 года
# Категория:Фильмы Барри Левинсона
# Категория:Фильмы по алфавиту
# Категория:Фильмы — лауреаты премии «Золотой медведь»
# Категория:Фильмы — лауреаты премии «Оскар»
# Категория:Фильмы-драмы США
#
# Категория:Фильмы по алфавиту
# [10]
#
#
#
# Рауль Стефан Пюньо (фр. Raoul Stéphane Pugno; 23 июня 1852, Монруж
#
# ['Пюньо, Рауль Стефан']
#  17%|█▋        | 5/30 [00:32<02:43,  6.55s/it]
# Категория:Академические музыканты Франции
# Категория:Композиторы XIX века
# Категория:Композиторы XX века
# Категория:Композиторы Франции
# Категория:Композиторы по алфавиту
# Категория:Музыканты по алфавиту
# Категория:Персоналии по алфавиту
# Категория:Пианисты XIX века
# Категория:Пианисты XX века
# Категория:Пианисты Франции
# Категория:Пианисты по алфавиту
# Категория:Родившиеся 23 июня
# Категория:Родившиеся в 1852 году
# Категория:Родившиеся в Монруже
# Категория:Умершие 3 января
# Категория:Умершие в 1914 году
# Категория:Умершие в Москве
#
# Категория:Персоналии по алфавиту
# Категория:Умершие в Москве
# Категория:Музыканты по алфавиту
# [1, 11, 13]
#
#
#
# «Некрома́нтик» (англ. Nekromantik)
#
# ['Некромантик', 'Некромантик 2', 'Некрофилия', 'Некромантик']
#  20%|██        | 6/30 [00:40<02:47,  6.97s/it]
# Категория:Незавершённые статьи о фильмах ужасов и триллерах
# Категория:Фильмы 1987 года
# Категория:Фильмы Йорга Буттгерайта
# Категория:Фильмы по алфавиту
# Категория:Фильмы ужасов 1987 года
# Категория:Фильмы ужасов Германии
#
# Категория:Фильмы по алфавиту
# [10]
#
#
#
# Икки Кита (яп. 北 一輝 Кита Икки, 3 апреля 1883 года, село Рёцу-Минато, в настоящее время город Садо префектуры Ниигата
#
# ['Кита, Икки', 'Кита, Икки']
#  23%|██▎       | 7/30 [00:46<02:35,  6.75s/it]
# Категория:Персоналии по алфавиту
# Категория:Писатели XX века
# Категория:Писатели Японии
# Категория:Писатели по алфавиту
# Категория:Расстрелянные в Японии
# Категория:Родившиеся 3 апреля
# Категория:Родившиеся в 1883 году
# Категория:Родившиеся на острове Садо
# Категория:Страницы, использующие волшебные ссылки ISBN
# Категория:Умершие 19 августа
# Категория:Умершие в 1937 году
# Категория:Умершие в префектуре Токио
# Категория:Фашисты Японии
# Категория:Философы XX века
# Категория:Философы Японии
# Категория:Философы по алфавиту
#
# Категория:Писатели по алфавиту
# Категория:Персоналии по алфавиту
# [1, 12]
#
#
#
# Тазмер
#
# ['Тазмер', 'Западный Тазмер', 'Восточный Тазмер', 'Кондас (приток Камы)']
#  27%|██▋       | 8/30 [00:56<02:45,  7.52s/it]
# Категория:Водные объекты по алфавиту
# Категория:Карточка реки: заполнить: Площадь бассейна
# Категория:Карточка реки: заполнить: Расход воды
# Категория:ПРО:ВО:Крайняя правка: в позапозапрошлом году
# Категория:ПРО:ВО:Размер статьи: менее 1000 символов
# Категория:Притоки Кондаса
# Категория:Реки Камского бассейнового округа
# Категория:Реки Усольского района Пермского края
# Категория:Реки до 5 км в длину
# Категория:Реки по алфавиту
#
# Категория:Реки по алфавиту
# Категория:Водные объекты по алфавиту
# [4, 6]
#
#
#
# Дорога в облака
#
# ['Дорога в облака', 'По дороге с облаками', 'Облака (комедия)', 'Куйбышевская железная дорога']
#  30%|███       | 9/30 [01:03<02:37,  7.49s/it]
# Категория:Альбомы 1994 года
# Категория:Альбомы группы «Браво»
# Категория:Альбомы по алфавиту
#
# Категория:Альбомы по алфавиту
# [14]
#
#
#
# Цукуми (яп. 津久見市 Цукуми-си)
#
# ['Цукуми', 'Цукуми']
#  33%|███▎      | 10/30 [01:07<02:07,  6.38s/it]
# Категория:Города префектуры Оита
# Категория:Населённые пункты по алфавиту
#
# Категория:Населённые пункты по алфавиту
# [2]
#
#
#
# Игорь Николаевич Панин
#
# ['Панин, Игорь Николаевич', 'Панин, Игорь', 'Панин', 'Панин, Андрей Владимирович']
# /Users/alexajax/anaconda3/lib/python3.5/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
#  37%|███▋      | 11/30 [01:15<02:11,  6.91s/it]
# Категория:Актёры XX века
# Категория:Актёры XXI века
# Категория:Актёры России
# Категория:Актёры СССР
# Категория:Актёры по алфавиту
# Категория:Каскадёры XX века
# Категория:Каскадёры XXI века
# Категория:Каскадёры России
# Категория:Каскадёры СССР
# Категория:Каскадёры по алфавиту
# Категория:Мастера спорта СССР
# Категория:Награждённые медалью ордена «За заслуги перед Отечеством» II степени
# Категория:Персоналии по алфавиту
# Категория:Персоны без указанного места рождения
# Категория:Режиссёры XX века
# Категория:Режиссёры XXI века
# Категория:Режиссёры России
# Категория:Режиссёры СССР
# Категория:Режиссёры по алфавиту
#
# Категория:Персоналии по алфавиту
# Категория:Актёры по алфавиту
# Категория:Актёры XXI века
# [1, 18, 37]
#
#
#
# Трикраты (укр. Трикрати)
#
# ['Трикраты', 'Заря (Вознесенский район, Николаевская область)', 'Вольный Яр', 'Актово']
#  40%|████      | 12/30 [01:23<02:10,  7.24s/it]
# Категория:Населённые пункты Вознесенского района (Николаевская область)
# Категория:Населённые пункты по алфавиту
# Категория:Населённые пункты, основанные в 1800 году
# Категория:Незавершённые статьи по географии Николаевской области
#
# Категория:Населённые пункты по алфавиту
# [2]
#
#
#
# «Девочка-скерцо»
#
# ['Девочка-скерцо', 'Хвоин', 'Королюк, Всеволод Емельянович', 'Арефьева, Ольга Викторовна']
#  43%|████▎     | 13/30 [01:31<02:05,  7.38s/it]
# Категория:Альбомы 1998 года
# Категория:Альбомы 2006 года
# Категория:Альбомы по алфавиту
#
# Категория:Альбомы по алфавиту
# [14]
#
#
#
# Андре́й Серге́евич Кайса́ров (16 (27) ноября 1782, Москва
#
# ['Кайсаров, Андрей Сергеевич']
#  47%|████▋     | 14/30 [01:34<01:39,  6.19s/it]
# Категория:Воспитанники московского университетского пансиона
# Категория:Исследователи славянского язычества
# Категория:Кайсаровы
# Категория:Материалы ЭСБЕ
# Категория:Персоналии по алфавиту
# Категория:Писатели России по алфавиту
# Категория:Писатели по алфавиту
# Категория:Преподаватели Императорского Дерптского университета
# Категория:Родившиеся 27 ноября
# Категория:Родившиеся 8 декабря
# Категория:Родившиеся в 1782 году
# Категория:Родившиеся в Москве
# Категория:Статьи со ссылками на Викитеку
# Категория:Страницы, использующие волшебные ссылки ISBN
# Категория:Умершие 26 мая
# Категория:Умершие 7 июня
# Категория:Умершие в 1813 году
# Категория:Умершие в Ханау
#
# Категория:Писатели по алфавиту
# Категория:Родившиеся в Москве
# Категория:Персоналии по алфавиту
# [1, 12, 17]
#
#
#
# Журуа́ (порт. Juruá)
#
# ['Журуа', 'Журуа (муниципалитет)', 'Журуа (значения)', 'Журуа (микрорегион)']
#  50%|█████     | 15/30 [01:44<01:49,  7.32s/it]
# Категория:Водные объекты по алфавиту
# Категория:Карточка реки: заполнить: Расход воды
# Категория:Карточка реки: заполнить: Регион
# Категория:Карточка реки: исправить: разногласие с Викиданными: Длина
# Категория:Незавершённые статьи по географии Бразилии
# Категория:Незавершённые статьи по географии Перу
# Категория:ПРО:ВО:Крайняя правка: в прошлом году
# Категория:Притоки Амазонки
# Категория:Реки Акри
# Категория:Реки Амазонаса
# Категория:Реки Перу
# Категория:Реки до 5000 км в длину
# Категория:Реки по алфавиту
#
# Категория:Реки по алфавиту
# Категория:Водные объекты по алфавиту
# [4, 6]
#
#
#
# Питер Хёг (дат. Peter Høeg; род. 17 мая 1957 года в Копенгагене)
#
# ['Хёг, Питер', 'Хёг, Питер']
#  53%|█████▎    | 16/30 [01:49<01:32,  6.58s/it]
# Категория:Датские писатели
# Категория:Персоналии по алфавиту
# Категория:Писатели Дании
# Категория:Писатели по алфавиту
# Категория:Питер Хёг
# Категория:Родившиеся 17 мая
# Категория:Родившиеся в 1957 году
# Категория:Статьи о писателях без ссылки на Викитеку
# Категория:Статьи со ссылками на Викицитатник
#
# Категория:Писатели по алфавиту
# Категория:Персоналии по алфавиту
# [1, 12]
#
#
#
# Фишбахау (нем. Fischbachau)
#
# ['Фишбахау', 'Фишбахау']
#  57%|█████▋    | 17/30 [01:53<01:14,  5.76s/it]
# Категория:Города Баварии
# Категория:Населённые пункты по алфавиту
# Категория:Незавершённые статьи по географии Баварии
#
# Категория:Населённые пункты по алфавиту
# [2]
#
#
#
# Демблин (польск. Dęblin)
#
# ['Демблин', 'Ивангородская крепость (Польша)', 'Список повятов Польши', 'Демблин']
#  60%|██████    | 18/30 [02:00<01:14,  6.20s/it]
# Категория:Города Люблинского воеводства
# Категория:Населённые пункты по алфавиту
# Категория:Незавершённые статьи по географии Польши
#
# Категория:Населённые пункты по алфавиту
# [2]
#
#
#
# Сабула (в переводе с хак. «Пихтовая»)
#
# ['Сабула', 'Сабула']
#  63%|██████▎   | 19/30 [02:04<01:01,  5.56s/it]
# Категория:Бассейн Чёрного Июса
# Категория:Водные объекты по алфавиту
# Категория:Карточка реки: Викиданные: используется свойство: код ГВР
# Категория:Карточка реки: заполнить: Бассейн
# Категория:Карточка реки: заполнить: Расход воды
# Категория:ПРО:ВО:Крайняя правка: в позапозапрошлом году
# Категория:Реки Верхнеобского бассейнового округа
# Категория:Реки Орджоникидзевского района Хакасии
# Категория:Реки до 50 км в длину
# Категория:Реки по алфавиту
# Категория:Страницы, использующие волшебные ссылки ISBN
#
# Категория:Реки по алфавиту
# Категория:Водные объекты по алфавиту
# [4, 6]
#
#
#
# Халмин
#
# ['Халмин', 'Щербинин, Олег Григорьевич', 'Список рек Камчатского края', 'Курикка, Матти']
#  67%|██████▋   | 20/30 [02:12<01:02,  6.24s/it]
# Категория:Водные объекты по алфавиту
# Категория:Карточка реки: Викиданные: используется свойство: код ГВР
# Категория:Карточка реки: заполнить: Координаты истока
# Категория:Карточка реки: заполнить: Координаты истока (указан исток)
# Категория:Карточка реки: заполнить: Площадь бассейна
# Категория:Карточка реки: заполнить: Расход воды
# Категория:Незавершённые статьи по географии Камчатского края
# Категория:ПРО:ВО:Крайняя правка: в прошлом году
# Категория:ПРО:ВО:Размер статьи: менее 1000 символов
# Категория:Притоки Камчатки
# Категория:Реки Анадыро-Колымского бассейнового округа
# Категория:Реки Камчатского края
# Категория:Реки до 50 км в длину
# Категория:Реки по алфавиту
#
# Категория:Реки по алфавиту
# Категория:Водные объекты по алфавиту
# [4, 6]
#
#
#
# Дирикон (нем. Dierikon)
#
# ['Дирикон', 'Дирикон']
#  70%|███████   | 21/30 [02:16<00:50,  5.64s/it]
# Категория:Города кантона Люцерн
# Категория:Населённые пункты по алфавиту
#
# Категория:Населённые пункты по алфавиту
# [2]
#
#
#
# ПараТайп
#
# ['ПараТайп', 'Свободные шрифты ПТ', 'Ефимов, Владимир Венедиктович', 'Символьный шрифт']
#  73%|███████▎  | 22/30 [02:26<00:55,  6.97s/it]
# Категория:Компании по алфавиту
# Категория:Компании, основанные в 1998 году
# Категория:Страницы, использующие волшебные ссылки ISBN
#
# Категория:Компании по алфавиту
# [20]
#
#
#
# Пье́тро Аарон (итал. Pietro Aaron), он же Пьетро Аронне (итал. Pietro Aronne), или Пьеро Арон (итал. Piero Aron; около 1480 года, Флоренция, Флорентийская республика
#
# ['Аарон, Пьетро']
#  77%|███████▋  | 23/30 [02:38<00:59,  8.55s/it]
# Категория:Музыканты по алфавиту
# Категория:Музыковеды Италии
# Категория:Персоналии по алфавиту
# Категория:Родившиеся в 1480 году
# Категория:Родившиеся во Флоренции
# Категория:Страницы, использующие волшебные ссылки ISBN
# Категория:Теоретики музыки
# Категория:Умершие в 1540 году
# Категория:Умершие в Венеции
#
# Категория:Персоналии по алфавиту
# Категория:Музыканты по алфавиту
# [1, 11]
#
#
#
# Фуабго
#
# ['Фуабго', 'Белая (приток Кубани)', 'Пшеха', 'Курджипс']
#  80%|████████  | 24/30 [02:46<00:49,  8.23s/it]
# Категория:Водные объекты по алфавиту
# Категория:Карточка реки: Викиданные: используется свойство: код ГВР
# Категория:Карточка реки: заполнить: Координаты истока
# Категория:Карточка реки: заполнить: Расход воды
# Категория:Незавершённые статьи по географии Краснодарского края
# Категория:ПРО:ВО:Крайняя правка: в прошлом году
# Категория:Реки Краснодарского края
# Категория:Реки Кубанского бассейнового округа
# Категория:Реки до 50 км в длину
# Категория:Реки по алфавиту
#
# Категория:Реки по алфавиту
# Категория:Водные объекты по алфавиту
# [4, 6]
#
#
#
# «Л'Этуаль»
#
# ["Л'Этуаль", 'Леон де Монморанси-Фоссё', 'Фликсекур (кантон)', 'Этуаль']
#  83%|████████▎ | 25/30 [02:53<00:39,  7.97s/it]
# Категория:Компании по алфавиту
# Категория:Компании, основанные в 1997 году
# Категория:Торговые сети России
#
# Категория:Компании по алфавиту
# [20]
#
#
#
# Лукиничи
#
# ['Лукиничи', 'Онцифор Лукинич', 'Мерлинское сельское поселение', '1367 год']
#  87%|████████▋ | 26/30 [03:01<00:30,  7.75s/it]
# Категория:НП Смоленской области без фотографий
# Категория:Населённые пункты Краснинского района (Смоленская область)
# Категория:Населённые пункты по алфавиту
# Категория:Незавершённые статьи по географии Смоленской области
# Категория:Статьи о населённых пунктах без категории на Викискладе
#
# Категория:Населённые пункты по алфавиту
# [2]
#
#
#
# Норосовка (в верховье Большая Норосовка)
#
# ['Норосовка', 'Кеть', 'Конда (приток Кети)', 'Утка (нижний приток Кети)']
#  90%|█████████ | 27/30 [03:08<00:23,  7.74s/it]
# Категория:Водные объекты по алфавиту
# Категория:Карточка реки: Викиданные: используется свойство: код ГВР
# Категория:Карточка реки: заполнить: Координаты истока
# Категория:Карточка реки: заполнить: Площадь бассейна
# Категория:Карточка реки: заполнить: Расход воды
# Категория:Незавершённые статьи по географии Красноярского края
# Категория:ПРО:ВО:Крайняя правка: в прошлом году
# Категория:ПРО:ВО:Размер статьи: менее 1000 символов
# Категория:Притоки Кети
# Категория:Реки Верхнеобского бассейнового округа
# Категория:Реки Енисейского района
# Категория:Реки до 50 км в длину
# Категория:Реки по алфавиту
#
# Категория:Реки по алфавиту
# Категория:Водные объекты по алфавиту
# [4, 6]
#
#
#
# Днепр (белор. Дняпро, Днепр[1], укр. Дніпро, Дніпер[2])
#
# ['Днепр', 'Днепр']
#  93%|█████████▎| 28/30 [03:14<00:14,  7.02s/it]
# Категория:Водные объекты по алфавиту
# Категория:Днепр
# Категория:Карточка реки: заполнить: Регион
# Категория:Карточка реки: исправить: Уклон реки
# Категория:Карточка реки: исправить: Устье/Бассейн
# Категория:Карточка реки: исправить: разногласие с Викиданными: Длина
# Категория:ПРО:ВО:Крайняя правка: менее полугода
# Категория:Пограничные реки
# Категория:Реки Витебской области
# Категория:Реки Гомельской области
# Категория:Реки Днепропетровской области
# Категория:Реки Запорожской области
# Категория:Реки Киева
# Категория:Реки Киевской области
# Категория:Реки Кировоградской области
# Категория:Реки Могилёва
# Категория:Реки Могилёвской области
# Категория:Реки Николаевской области
# Категория:Реки Полтавской области
# Категория:Реки Смоленской области
# Категория:Реки Херсонской области
# Категория:Реки Черкасской области
# Категория:Реки Черниговской области
# Категория:Реки до 5000 км в длину
# Категория:Реки по алфавиту
# Категория:Реки, впадающие в Чёрное море
# Категория:Статьи со ссылками на Викицитатник
# Категория:Страницы, использующие волшебные ссылки ISBN
#
# Категория:Реки по алфавиту
# Категория:Водные объекты по алфавиту
# [4, 6]
#
#
#
# Райко Йоанов (Иванов) Жинзифов (при рождении Ксенофонт Дзиндзифи, впоследствии изменил имя на исконно болгарское; 15 февраля 1839, Велес, Македония, Османская империя,
#
# ['Жинзифов, Райко']
#  97%|█████████▋| 29/30 [03:18<00:06,  6.37s/it]
# Категория:Болгарские поэты
# Категория:Журналисты Болгарии
# Категория:Материалы ЭСБЕ
# Категория:Переводчики поэзии на болгарский язык
# Категория:Персоналии по алфавиту
# Категория:Писатели Болгарии
# Категория:Писатели по алфавиту
# Категория:Поэты Болгарии
# Категория:Преподаватели 2-й Московской гимназии
# Категория:Родившиеся 15 февраля
# Категория:Родившиеся в 1839 году
# Категория:Родившиеся в Велесе
# Категория:Статьи о писателях без ссылки на Викитеку
# Категория:Умершие 15 февраля
# Категория:Умершие в 1877 году
# Категория:Умершие в Москве
#
# Категория:Писатели по алфавиту
# Категория:Персоналии по алфавиту
# Категория:Умершие в Москве
# [1, 12, 13]
#
#
#
# Рови́го (итал. и вен. Rovigo)
#
# ['Ровиго', 'Ровиго (провинция)', 'Ровиго', 'Ровиго (провинция)']
# 100%|██████████| 30/30 [03:26<00:00,  6.64s/it]
# Категория:Города Италии
# Категория:Коммуны провинции Ровиго
# Категория:Населённые пункты по алфавиту
# Категория:Незавершённые статьи по географии Италии
#
# Категория:Населённые пункты по алфавиту
# [2]

# %%
import unicodedata
def strip_accents(s):
    s = re.sub("\[[^\ ]+\]",' ',s)
    return ''.join(c for c in unicodedata.normalize('NFD', s)
                  if unicodedata.category(c) != 'Mn')

# %%
for p in data_categories:
    print(" ".join(list(map(str, p))))
# Out:
# 4 6
# 4 6
# 4 6
# 10
# 1 11 13
# 10
# 1 12
# 4 6
# 14
# 2
# 1 18 37
# 2
# 14
# 1 12 17
# 4 6
# 1 12
# 2
# 2
# 4 6
# 4 6
# 2
# 20
# 1 11
# 4 6
# 20
# 2
# 4 6
# 4 6
# 1 12 13
# 2

# %%
wikipedia.search("")
